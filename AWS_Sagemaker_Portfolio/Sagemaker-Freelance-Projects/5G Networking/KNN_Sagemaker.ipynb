# %% [markdown]
# # k-nearest neighbor algorithm:
#
# This algorithm is used to solve the classification model problems. K-nearest neighbor or K-NN algorithm basically creates an imaginary boundary to classify the data. When new data points come in, the algorithm will try to predict that to the nearest of the boundary line.

# %% [markdown]
# ![aa.gif](attachment:aa.gif)

# %%
# import necessary libraries
import pandas as pd
import numpy as np

# %%
# Data Load from s3 Bucket. Data Location: s3://bing1219/sim1.csv

df = pd.read_csv("s3://bing1219/sim1.csv")
df
# Out:
#         Time  BS_ID  BS_LOC_X  BS_LOC_Y  ANT_ID  ANT_SEC  TRX_ID    TRX_X  \
# 0          0      0    0.0000         0       0        0      99   0.2500
# 1          0      0    0.0000         0       0        0      98   0.2500
# 2          0      0    0.0000         0       0        0      97   0.2500
# 3          0      0    0.0000         0       0        0      96   0.2500
# 4          0      0    0.0000         0       0        0      95   0.2500
# ...      ...    ...       ...       ...     ...      ...     ...      ...
# 178995   999      2   17.3205       -10       2      240      88  16.8939
# 178996   999      2   17.3205       -10       2      240      87  17.4904
# 178997   999      2   17.3205       -10       2      240      86  16.9006
# 178998   999      2   17.3205       -10       2      240      85  17.4837
# 178999   999      2   17.3205       -10       2      240      84  16.9073
#
#            TRX_Y  TRX_ANG  ...   UE_LOC_Y  MAX_DR_(bits)  DEMAND_DR_(bits)  \
# 0        0.38700        0  ...   3.185660            146                68
# 1       -0.38700        0  ...  -3.746920            152               104
# 2        0.37926        0  ...   2.572930            152               110
# 3       -0.37926        0  ...   2.934360            135                31
# 4        0.37152        0  ...   0.307584            160                25
# ...          ...      ...  ...        ...            ...               ...
# 178995 -10.04240        0  ...  -1.559620            109                55
# 178996 -10.38680        0  ... -11.473800            160               116
# 178997 -10.04620        0  ...  -4.819940            108                75
# 178998 -10.38290        0  ... -12.707500            140                85
# 178999 -10.05010        0  ... -20.730000            144               136
#
#         REAL_DR_(bits)  BS_Trans_PWR_(W)  UE_Rec_PWR_(W)  RSRP_(dBm)  \
# 0                   68      2.700000e-12    2.250000e-12    -86.4780
# 1                  104      3.630000e-12    3.030000e-12    -85.1879
# 2                  110      3.550000e-12    2.960000e-12    -85.2853
# 3                   31      1.440000e-12    1.200000e-12    -89.2190
# 4                   25      1.870000e-11    1.560000e-11    -78.0631
# ...                ...               ...             ...         ...
# 178995              55      5.800000e-13    4.830000e-13    -93.1612
# 178996             116      1.830000e-11    1.520000e-11    -78.1700
# 178997              75      5.610000e-13    4.670000e-13    -93.3024
# 178998              85      2.150000e-12    1.790000e-12    -87.4623
# 178999             136      2.380000e-12    1.980000e-12    -87.0284
#
#         RSSI_(dBm)  RSRQ_(dB)  DDR_(%)
# 0         -55.6862   -10.7918      0.0
# 1         -54.3961   -10.7918      0.0
# 2         -54.4935   -10.7918      0.0
# 3         -58.4272   -10.7918      0.0
# 4         -47.2713   -10.7918      0.0
# ...            ...        ...      ...
# 178995    -62.3694   -10.7918      0.0
# 178996    -47.3782   -10.7918      0.0
# 178997    -62.5106   -10.7918      0.0
# 178998    -56.6705   -10.7918      0.0
# 178999    -56.2366   -10.7918      0.0
#
# [179000 rows x 23 columns]

# %%
# select only 3 columns like: RSRP , RSSI, RSRQ 
X = df[['RSRP_(dBm)', 'RSSI_(dBm)', 'RSRQ_(dB)']]

# %%
# The Python abs() function return the absolute value and remove the negative sign of a number in
data = X.abs()

# %% [markdown]
# ## Formulas to Calculate the RSRP, RSSI, RSRQ
#
# . 2 is define for strong signal
#
# . 1 is define for medium signal
#
# . 0 is define for week signal

# %%
conditions = [
    (data['RSRP_(dBm)'] <= 80),
    (data['RSRP_(dBm)'] > 80) & (data['RSRP_(dBm)'] < 90),
    (data['RSRP_(dBm)'] > 90) & (data['RSRP_(dBm)'] < 100),
    ]
values = [2, 1, 0]
data['RSRP_bandwith'] = np.select(conditions, values)

# %%
conditions2 = [
    (df['RSSI_(dBm)'] <= 70),
    (df['RSSI_(dBm)'] > 70) & (df['RSSI_(dBm)'] < 85),
    (df['RSSI_(dBm)'] > 85) & (df['RSSI_(dBm)'] < 100),
    ]

values = [2, 1, 0] 
data['RSSI_bandwith'] = np.select(conditions2, values)

# %%
conditions = [
    (df['RSRQ_(dB)'] <= 10),
    (df['RSRQ_(dB)'] > 10) & (df['RSRQ_(dB)'] < 15),
    (df['RSRQ_(dB)'] > 15) & (df['RSRQ_(dB)'] < 20),
    ]
values = [2, 1, 0]
data['RSRQ_bandwith'] = np.select(conditions, values)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179000 entries, 0 to 178999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   RSRP_(dBm)     179000 non-null  float64
#  1   RSSI_(dBm)     179000 non-null  float64
#  2   RSRQ_(dB)      179000 non-null  float64
#  3   RSRP_bandwith  179000 non-null  int64
#  4   RSSI_bandwith  179000 non-null  int64
#  5   RSRQ_bandwith  179000 non-null  int64
# dtypes: float64(3), int64(3)
# memory usage: 8.2 MB

# %%
data.isnull().sum()
# Out:
# RSRP_(dBm)       0
# RSSI_(dBm)       0
# RSRQ_(dB)        0
# RSRP_bandwith    0
# RSSI_bandwith    0
# RSRQ_bandwith    0
# dtype: int64

# %% [markdown]
# ## Splitting Trian and Test Data

# %%
data = data.sample(frac=1, random_state=42)
data1 = data.copy()
y = data1[['RSRP_bandwith', 'RSSI_bandwith', 'RSRQ_bandwith']]
y
# Out:
#         RSRP_bandwith  RSSI_bandwith  RSRQ_bandwith
# 97877               0              2              2
# 170143              2              2              2
# 36446               1              2              2
# 7492                2              2              2
# 153444              1              2              2
# ...               ...            ...            ...
# 119879              0              2              2
# 103694              0              2              2
# 131932              2              2              2
# 146867              1              2              2
# 121958              1              2              2
#
# [179000 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
train_data, val_data = train_test_split(data, test_size=0.01)

# %%
print(train_data.shape)
print(val_data.shape)
# Out:
# (177210, 6)
# (1790, 6)

# %% [markdown]
# ## Data Save in csv file

# %%
train_data.to_csv('sagemaker_training_dataset.csv', index=False)
val_data.to_csv('sagemaker_validation_dataset.csv', index=False)

# %% [markdown]
# ## Store Data in s3

# %%
import sagemaker

print(sagemaker.__version__)

sess = sagemaker.Session()
bucket = sess.default_bucket()

prefix = 'KNN_prefix'
training_data_path = sess.upload_data(path='sagemaker_training_dataset.csv', key_prefix=prefix + '/input/training')
validation_data_path = sess.upload_data(path='sagemaker_validation_dataset.csv', key_prefix=prefix + '/input/validation')
output   = 's3://{}/{}/output/'.format(bucket,prefix)
print(training_data_path)
print(validation_data_path)
print(output)
# Out:
# 2.110.0
# s3://sagemaker-us-east-1-811710284692/KNN_prefix/input/training/sagemaker_training_dataset.csv
# s3://sagemaker-us-east-1-811710284692/KNN_prefix/input/validation/sagemaker_validation_dataset.csv
# s3://sagemaker-us-east-1-811710284692/KNN_prefix/output/

# %% [markdown]
# ## Training job
#
# ### Use Sagmaker SKLearn Frame work
#
# You can use Amazon SageMaker to train and deploy a model using custom Scikit-learn code. The SageMaker Python SDK Scikit-learn estimators and models and the SageMaker open-source Scikit-learn containers make writing a Scikit-learn script and running it in SageMaker easier.

# %%
import sagemaker
from sagemaker.sklearn import SKLearn

role = sagemaker.get_execution_role()
#role = 'arn:aws:iam::0123456789012:role/Sagemaker-fullaccess'
hyperparameters = {
    "random_state": 0,
}

sk = SKLearn(entry_point='knn.py', 
                          role=role,
                          instance_count=1, 
                          instance_type='ml.m5.xlarge',
                          framework_version='0.20.0',                         
                          script_mode=True,
                          output_path=output,
                          hyperparameters = hyperparameters)

# %%
sk.fit({'training':training_data_path, 'validation':validation_data_path})
# Out:
# 2022-10-17 09:20:05 Starting - Starting the training job...
# 2022-10-17 09:20:30 Starting - Preparing the instances for trainingProfilerReport-1665998405: InProgress
# ......
# 2022-10-17 09:21:33 Downloading - Downloading input data...
# 2022-10-17 09:21:52 Training - Downloading the training image...
# 2022-10-17 09:22:30 Training - Training image download completed. Training in progress..2022-10-17 09:22:30,155 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2022-10-17 09:22:30,160 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-10-17 09:22:30,169 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2022-10-17 09:22:30,570 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-10-17 09:22:30,582 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-10-17 09:22:30,596 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-10-17 09:22:30,607 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training",
#         "validation": "/opt/ml/input/data/validation"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "random_state": 0
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-scikit-learn-2022-10-17-09-20-05-497",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-811710284692/sagemaker-scikit-learn-2022-10-17-09-20-05-497/source/sourcedir.tar.gz",
#     "module_name": "knn",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.m5.xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "knn.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"random_state":0}
# SM_USER_ENTRY_POINT=knn.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=knn
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-811710284692/sagemaker-scikit-learn-2022-10-17-09-20-05-497/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"random_state":0},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-scikit-learn-2022-10-17-09-20-05-497","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-811710284692/sagemaker-scikit-learn-2022-10-17-09-20-05-497/source/sourcedir.tar.gz","module_name":"knn","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"knn.py"}
# SM_USER_ARGS=["--random_state","0"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_HP_RANDOM_STATE=0
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
# Invoking script with the following command:
# /miniconda3/bin/python knn.py --random_state 0
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/externals/cloudpickle/cloudpickle.py:47: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# /opt/ml/input/data/training
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/externals/cloudpickle/cloudpickle.py:47: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/externals/cloudpickle/cloudpickle.py:47: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/externals/cloudpickle/cloudpickle.py:47: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# 2022-10-17 09:22:34,626 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2022-10-17 09:22:56 Uploading - Uploading generated training model
# 2022-10-17 09:22:56 Completed - Training job completed
# Training seconds: 83
# Billable seconds: 83

# %% [markdown]
# # Sagemaker Endpoint

# %%
from time import strftime, gmtime
timestamp = strftime('%d-%H-%M-%S', gmtime())

endpoint_name = 'xgb-model-'+timestamp
print(endpoint_name)
# Out:
# xgb-model-17-09-23-24

# %%
knn_predictor = sk.deploy(endpoint_name=endpoint_name, 
                        initial_instance_count=1, 
                        instance_type='ml.t2.medium')
# Out:
# -------!

# %% [markdown]
# # Prepare Test Data

# %%
# Load some samples, drop labels, and one-hot encode
payload = val_data[:10].drop(['RSRP_bandwith' , 'RSSI_bandwith' , 'RSRQ_bandwith'], axis=1)
payload = payload.to_csv(header=False,index=False).rstrip('\n')
print(payload)
# Out:
# 94.0192,63.2274,10.7918
# 81.8475,51.0557,10.7918
# 77.6234,46.8316,10.7918
# 77.6234,46.8316,10.7918
# 98.6713,67.8794,10.7918
# 77.6234,46.8316,10.7918
# 84.9198,54.128,10.7918
# 77.6923,46.9005,10.7918
# 83.0444,52.2526,10.7918
# 81.8475,51.0557,10.7918

# %% [markdown]
# # prediction

# %%
knn_predictor.serializer = sagemaker.serializers.CSVSerializer()
knn_predictor.deserializer = sagemaker.deserializers.CSVDeserializer()

response = knn_predictor.predict(payload)

print(response)
# Out:
# [['0', '2', '2'], ['1', '2', '2'], ['2', '2', '2'], ['2', '2', '2'], ['0', '2', '2'], ['2', '2', '2'], ['1', '2', '2'], ['2', '2', '2'], ['1', '2', '2'], ['1', '2', '2']]

# %%
y_true = val_data[['RSRP_bandwith', 'RSSI_bandwith' ,'RSRQ_bandwith']]
y_true.head(10)
# Out:
#         RSRP_bandwith  RSSI_bandwith  RSRQ_bandwith
# 40797               0              2              2
# 61642               1              2              2
# 7710                2              2              2
# 55956               2              2              2
# 163637              0              2              2
# 121988              2              2              2
# 75731               1              2              2
# 73657               2              2              2
# 4683                1              2              2
# 109614              1              2              2

# %% [markdown]
# # Delete Endpoint

# %%
knn_predictor.delete_endpoint()
