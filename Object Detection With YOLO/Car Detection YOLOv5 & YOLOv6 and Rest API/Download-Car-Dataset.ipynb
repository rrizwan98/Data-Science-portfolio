# %% [markdown]
# # **How to prepare your own customized dataset using Open Images Dataset V4**
#
# Dataset is the fuel which runs any deep learning model. Without dataset, it is just a car without petrol we can’t move ahead. For quite a while I was working on Object detection algorithms. The first problem I would encounter is to find sufficient labelled data to prepare a customized dataset. I would end up searching for various dataset resources such as Google Dataset search or Kaggle to meet my requirements.
#
# This repository has really made life easier (at least for me 😉). This amazing toolkit allows you to download images from OID v4 seamlessly. The installation is easy and clearly mentioned in the readme file. The toolkit is loaded with a variety of options.OIDv4 Toolkit allows you to download any particular class of interest. The toolkit can be cloned by the following command [Read more](https://medium.com/@c.n.veeraganesh/how-to-prepare-your-own-customized-dataset-using-open-images-dataset-v4-8dfce9b9e147)
#
# git clone https://github.com/EscVM/OIDv4_ToolKit.git

# %%
# !git clone https://github.com/EscVM/OIDv4_ToolKit.git
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 422, done.
# remote: Total 422 (delta 0), reused 0 (delta 0), pack-reused 422
# Receiving objects: 100% (422/422), 34.08 MiB | 27.79 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
# !pip3 install -r /content/OIDv4_ToolKit/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 3.9 MB 8.4 MB/s
# ...
#      |████████████████████████████████| 548 kB 70.8 MB/s
# ...
#      |████████████████████████████████| 79 kB 10.7 MB/s
# ...
#      |████████████████████████████████| 9.0 MB 44.2 MB/s
# ...
#      |████████████████████████████████| 139 kB 68.3 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.8
#     Uninstalling rsa-4.8:
#       Successfully uninstalled rsa-4.8
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.17.1
#     Uninstalling docutils-0.17.1:
#       Successfully uninstalled docutils-0.17.1
# ...

# %%
# !python /content/OIDv4_ToolKit/main.py downloader --classes Car --type_csv train --limit 800
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Car.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] y
# ...145%, 0 MB, 46185 KB/s, 0 seconds passed
# ...

# %%
# !python /content/OIDv4_ToolKit/main.py downloader --classes Car --type_csv test --limit 300
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Car.
#    [ERROR] | Missing the test-annotations-bbox.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] y
# ...100%, 49 MB, 64613 KB/s, 0 seconds passed
# [DOWNLOAD] | File test-annotations-bbox.csv downloaded into OID/csv_folder/test-annotations-bbox.csv.
# ...

# %% [markdown]
# ### **Thank you so much.**
#
# # **Raza Rizwan Data Scientist & MLOps Engineer.**
#
# portfolio links is below the GitHub overview page
#
# [Here is my Portfolio link](https://github.com/rrizwan98)
