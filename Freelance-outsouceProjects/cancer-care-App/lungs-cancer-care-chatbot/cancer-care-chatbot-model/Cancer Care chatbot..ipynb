# %%
# import nessessory library
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('/content/cancerChatbot.json').read()
intents = json.loads(data_file)

# %%
for intent in intents['intents']:
    for pattern in intent['question']:

        # take each word and tokenize it
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # adding documents
        documents.append((w, intent['context']))

        # adding classes to our class list
        if intent['context'] not in classes:
            classes.append(intent['context'])
        print(pattern)
        

words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))
# Out:
# Hi
# How are you
# Is anyone there?
# Hello
# Good day
# Bye
# See you later
# Goodbye
# Nice chatting to you, bye
# Till next time
# Thanks
# Thank you
# That's helpful
# Awesome, thanks
# Thanks for helping me
# How you could help me?
# What you can do?
# What help you provide?
# How you can be helpful?
# What support is offered
# who are you?
# what is lungs cancer?
# lungs cancer?
# پھیپھڑوں کا کینسر کیا ہے؟
# پھیپھڑوں کا کینسر کیسے پھیلتا ہے۔
# lungs cancer kyia hy?
# How does lungs cancer spread?
# lungs cancer spread?
# spread lungs cancer ?
# پھیپھڑوں کا کینسر کیسے پھیلتا ہے۔
# lungs cancer ksay phelta hy?
# What are the symptoms of lungs cancer?
# symptoms of lungs cancer?
# پھیپھڑوں کے کینسر کی علامات کیا ہیں؟
# lungs cancer symptoms?
# lungs cacner ka symptoms kyia hn?
# What are the Causes of lung cancer?
# Causes of lung cancer?
# پھیپھڑوں کے کینسر کی وجوہات کیا ہیں؟
# lungs cancer kin wajha sa phelta hy?
# lungs cancer causes
# How do I know if it is lungs cancer or just the common cough?
# lungs cancer cough or normal cough
# normal cough or lungs cancer cough?
# مجھے کیسے پتہ چلے گا کہ یہ پھیپھڑوں کا کینسر ہے یا صرف عام کھانسی؟
# lungs cancer Khansi or normal khansi mn kyia farq hy?
# Early signs and symptoms of lung cancer
# early symptoms of lungs cancer
# پھیپھڑوں کے کینسر کی ابتدائی علامات اور علامات
# first stage of lungs cancer symptoms
# lungs cancer ki phali stage kyia hy?
# Breathing changes in lungs cancer
# breath changes
# khansi ki tabdeeli ka ksay pta chla ga?
# shortness of breath
# wheezing
# wheezing of lung cancer
# lungs cancer wheezing?
# How do I know if it is lungs cancer or just the common body pain?
# body pain
# lungs cancer body pain?
# what are the Less common signs and symptoms of lung cancer
# Less common signs and symptoms lungs cancer
# lungs cancer ki kyia alamat hyn?
# what Are the symptoms of lung cancer different for men or women?
# مردوں یا عورتوں میں پھیپھڑوں کے کینسر کی علامات ہیں؟
# symptoms of lung cancer different men or women?
# lung cancer different men or women
# difference between lung cancer men and women
# men or woman mn lungs cancer mn farq btyn?
# what Are the Small cell lung cancer symptoms?   چھوٹے سیل پھیپھڑوں کے کینسر کی علامات کیا ہیں؟
# Small cell lung cancer symptoms
# چھوٹے سیل پھیپھڑوں کے کینسر کی علامات کیا ہیں؟
# what Are the End-stage symptoms for lung cancer?
# End stage symptoms for lung cancer?
# last stage symptoms for lung cancer??
# lungs cancer ki akhri stage kyia hy?
# پھیپھڑوں کے کینسر کے آخری مرحلے کی علامات کیا ہیں؟
# Screening of lung cancer?
# Screening of lung cancer Screening?
# lungs cancer screening?
# lungs cancer ki screening kyia hn?
# what are the People at higher risk for lung cancer?
# کن لوگوں کو پھیپھڑوں کے کینسر کا زیادہ خطرہ ہے؟
effects of smoking for women vs. men  men or women mn smoking ka kyia nuksanat hn?  خواتین بمقابلہ مردوں پر سگریٹ نوشی کے کیا اثرات ہیں', 'End-stage last symptoms for lung cancer  lungs cancer ki akhri stage kyia hy  پھیپھڑوں کے کینسر کے آخری مرحلے کی علامات کیا ہیں', 'Genetics and hormones in lung cancer   پھیپھڑوں کے کینسر میں جینیات اور ہارمونز کیا ہیں؟', 'Less common signs and symptoms lungs cancer lungs cancer ki kyia alamat hyn', 'Lung Cancer Symptoms in Women  womwn mn lungs cancer ki kyia alamat hyn?  خواتین میں پھیپھڑوں کے کینسر کی علامات', 'Paraneoplastic syndromes men and woman', 'Screening for lung cancer  lungs cancer ki screening kyia hn ', 'Small cell lung cancer symptoms', 'Who is at risk of developing severe lungs cancer  kin logo ko lungs cancer ho sakta hy   کیا حاملہ خواتین پھیپھڑوں کے کینسر کا زیادہ شکار ہوتی ہیں اور کیا یہ جنین کو نقصان پہنچائے گی', 'body pain', 'goodbye', 'greeting', 'how many percent of smoking is responsible for lungs cancer   smoking sa kitna persent lungs cancer hosakta hy  کتنے فیصد تمباکو نوشی پھیپھڑوں کے کینسر کے لیے ذمہ دار ہے', 'less common symptoms of lungs cancer   پھیپھڑوں کے کینسر کی کم عام علامات؟', 'lungs cancer   پھیپھڑوں کا کینسر کیا ہے؟', 'lungs cancer cough lungs cacner cough or normal cough lungs cancer Khansi or normal khansi mn kyia farq hy مجھے کیسے پتہ چلے گا کہ یہ پھیپھڑوں کا کینسر ہے یا صرف عام کھانسی؟', 'lungs cancer in pregnancy  lungs cancer during pregnancy  کیا حاملہ خواتین پھیپھڑوں کے کینسر کا زیادہ شکار ہوتی ہیں اور کیا یہ جنین کو نقصان پہنچائے گی', 'lungs cancer spread پھیپھڑوں کا کینسر کیسے پھیلتا ہے۔ lungs cancer ksay phelta hy?', 'medicne', 'mn cancer sa api hifazat ksay kr sakta hon   protect myself and prevent the spread of lungs cancer   میں اپنی حفاظت اور پھیپھڑوں کے کینسر کے پھیلاؤ کو روکنے کے لیے کیا کر سکتا ہوں', 'options', 'symptoms of lung cancer different for men or women  difference between lung cancer men and women     men or woman mn lungs cancer mn farq btyn  مردوں یا عورتوں میں پھیپھڑوں کے کینسر کی علامات ہیں؟', 'symptoms of lungs cancer پھیپھڑوں کے کینسر کی علامات کیا ہیں؟  ungs cacner ksay phelta hy ', 'thanks', 'what are the Superior vena cava syndrome  superior vena canva syndrome   سپیریئر وینا کاوا سنڈروم کیا ہیں؟', 'wheezing of lung cancer']
# 244 unique lemmatized words ["'s", ',', 'akhri', 'alamat', 'and', 'antibiotic', 'anyone', 'api', 'are', 'at', 'awesome', 'be', 'between', 'body', 'breath', 'breathing', 'btyn', 'bye', 'cacner', 'can', 'cancer', 'canva', 'cause', 'cava', 'cell', 'change', 'chatting', 'chla', 'common', 'cough', 'could', 'day', 'developing', 'difference', 'different', 'do', 'doe', 'during', 'early', 'effect', 'effective', 'end', 'end-stage', 'farq', 'fetus', 'first', 'for', 'ga', 'genetics', 'good', 'goodbye', 'harm', 'hello', 'help', 'helpful', 'helping', 'hi', 'hifazat', 'higher', 'hn', 'ho', 'hon', 'hormone', 'hosakta', 'how', 'hy', 'hyn', 'i', 'if', 'in', 'is', 'it', 'just', 'ka', 'khansi', 'khatra', 'ki', 'kin', 'kitna', 'know', 'ko', 'kr', 'krti', 'ksay', 'kyia', 'last', 'later', 'le', 'logo', 'lung', 'many', 'me', 'men', 'mn', 'more', 'myself', 'next', 'nice', 'normal', 'nuksanat', 'of', 'offered', 'or', 'pa', 'pain', 'paraneoplastic', 'people', 'percent', 'persent', 'phali', 'phelta', 'pregnancy', 'pregnant', 'prevent', 'preventing', 'protect', 'provide', 'pta', 'rate', 'responsible', 'risk', 'sa', 'sakta', 'screening', 'see', 'severe', 'shortness', 'sign', 'small', 'smoking', 'spread', 'stage', 'superior', 'support', 'survival', 'susceptible', 'symptom', 'syndrome', 'tabdeeli', 'thank', 'thanks', 'that', 'the', 'there', 'till', 'time', 'to', 'treating', 'vena', 'vs.', 'wajha', 'what', 'wheezing', 'who', 'will', 'woman', 'you', 'zayida', 'آخری', 'ابتدائی', 'اثرات', 'اور', 'اپنی', 'اینٹی', 'بائیوٹکس', 'بقا', 'بمقابلہ', 'تمباکو', 'تھام', 'جنین', 'جینیات', 'حاملہ', 'حفاظت', 'خطرہ', 'خواتین', 'دار', 'درمیان', 'ذمہ', 'روک', 'روکنے', 'زیادہ', 'سنڈروم', 'سپیریئر', 'سکتا', 'سگریٹ', 'سیل', 'شدید', 'شرح', 'شکار', 'صرف', 'عام', 'علاج', 'علامات', 'علامات؟', 'عورتوں', 'فرق؟', 'فیصد', 'لوگوں', 'لیے', 'مجھے', 'مرحلے', 'مردوں', 'موثر', 'میں', 'نقصان', 'نوشی', 'وجوہات', 'وینا', 'پتہ', 'پر', 'پھیلاؤ', 'پھیلتا', 'پھیپھڑوں', 'پہنچائے', 'چلے', 'چھوٹے', 'کا', 'کاوا', 'کتنے', 'کر', 'کس', 'کم', 'کن', 'کو', 'کھانسی؟', 'کہ', 'کی', 'کیا', 'کیسے', 'کینسر', 'کے', 'گا', 'گی؟', 'ہارمونز', 'ہوتی', 'ہونے', 'ہوں؟', 'ہیں', 'ہیں؟', 'ہے', 'ہے؟', 'ہے۔', 'یا', 'یہ']

# %%
pickle.dump(words,open('cancer_care_words1.1.pkl','wb'))
pickle.dump(classes,open('cancer_care_classes1.1.pkl','wb'))

# %%
# initializing training data
training = []
output_empty = [0] * len(classes)
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])

# %%
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# %%
# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
# sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer="adam", metrics=['accuracy'])

# %%
#fitting model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=16, verbose=1)
# Out:
# Epoch 1/200
# 9/9 [==============================] - 3s 4ms/step - loss: 3.5003 - accuracy: 0.0214
# Epoch 2/200
# 9/9 [==============================] - 0s 4ms/step - loss: 3.4691 - accuracy: 0.0571
# Epoch 3/200
# 9/9 [==============================] - 0s 4ms/step - loss: 3.4442 - accuracy: 0.0643
# Epoch 4/200
# 9/9 [==============================] - 0s 5ms/step - loss: 3.3761 - accuracy: 0.0429
# Epoch 5/200
# 9/9 [==============================] - 0s 5ms/step - loss: 3.3710 - accuracy: 0.0643
# Epoch 6/200
# 9/9 [==============================] - 0s 5ms/step - loss: 3.3309 - accuracy: 0.0786
# Epoch 7/200
# 9/9 [==============================] - 0s 4ms/step - loss: 3.3271 - accuracy: 0.0857
# Epoch 8/200
# 9/9 [==============================] - 0s 4ms/step - loss: 3.3026 - accuracy: 0.0857
# Epoch 9/200
# 9/9 [==============================] - 0s 4ms/step - loss: 3.2126 - accuracy: 0.1857
# Epoch 10/200
# 9/9 [==============================] - 0s 4ms/step - loss: 3.2013 - accuracy: 0.1929
# Epoch 11/200
# 9/9 [==============================] - 0s 4ms/step - loss: 3.0955 - accuracy: 0.2000
# Epoch 12/200
# 9/9 [==============================] - 0s 4ms/step - loss: 3.1306 - accuracy: 0.2000
# Epoch 13/200
# 9/9 [==============================] - 0s 4ms/step - loss: 3.0762 - accuracy: 0.1643
# Epoch 14/200
# 9/9 [==============================] - 0s 4ms/step - loss: 3.0561 - accuracy: 0.2357
# Epoch 15/200
# 9/9 [==============================] - 0s 4ms/step - loss: 2.9242 - accuracy: 0.2786
# Epoch 16/200
# 9/9 [==============================] - 0s 4ms/step - loss: 2.9239 - accuracy: 0.2857
# Epoch 17/200
# 9/9 [==============================] - 0s 4ms/step - loss: 2.8492 - accuracy: 0.2929
# Epoch 18/200
# 9/9 [==============================] - 0s 4ms/step - loss: 2.6676 - accuracy: 0.3714
# Epoch 19/200
# 9/9 [==============================] - 0s 5ms/step - loss: 2.6839 - accuracy: 0.3500
# Epoch 20/200
# 9/9 [==============================] - 0s 4ms/step - loss: 2.5939 - accuracy: 0.3643
# Epoch 21/200
# 9/9 [==============================] - 0s 4ms/step - loss: 2.5459 - accuracy: 0.3500
# Epoch 22/200
# 9/9 [==============================] - 0s 4ms/step - loss: 2.4842 - accuracy: 0.3714
# Epoch 23/200
# 9/9 [==============================] - 0s 4ms/step - loss: 2.3526 - accuracy: 0.4429
# Epoch 24/200
# 9/9 [==============================] - 0s 4ms/step - loss: 2.2590 - accuracy: 0.4500
# Epoch 25/200
# 9/9 [==============================] - 0s 5ms/step - loss: 2.2487 - accuracy: 0.4571
# Epoch 26/200
# 9/9 [==============================] - 0s 4ms/step - loss: 2.1617 - accuracy: 0.4429
# Epoch 27/200
# 9/9 [==============================] - 0s 4ms/step - loss: 2.1053 - accuracy: 0.4857
# Epoch 28/200
# 9/9 [==============================] - 0s 4ms/step - loss: 1.9989 - accuracy: 0.5000
# Epoch 29/200
# 9/9 [==============================] - 0s 4ms/step - loss: 1.9095 - accuracy: 0.5143
# Epoch 30/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.9746 - accuracy: 0.5214
# Epoch 31/200
# 9/9 [==============================] - 0s 4ms/step - loss: 1.8794 - accuracy: 0.5429
# Epoch 32/200
# 9/9 [==============================] - 0s 4ms/step - loss: 1.8388 - accuracy: 0.5071
# Epoch 33/200
# 9/9 [==============================] - 0s 4ms/step - loss: 1.7558 - accuracy: 0.5357
# Epoch 34/200
# 9/9 [==============================] - 0s 4ms/step - loss: 1.6885 - accuracy: 0.5571
# Epoch 35/200
# 9/9 [==============================] - 0s 4ms/step - loss: 1.5671 - accuracy: 0.5857
# Epoch 36/200
# 9/9 [==============================] - 0s 4ms/step - loss: 1.6659 - accuracy: 0.6071
# Epoch 37/200
# 9/9 [==============================] - 0s 4ms/step - loss: 1.5266 - accuracy: 0.6786
# Epoch 38/200
# 9/9 [==============================] - 0s 4ms/step - loss: 1.2752 - accuracy: 0.7000
# Epoch 39/200
# 9/9 [==============================] - 0s 4ms/step - loss: 1.3520 - accuracy: 0.6357
# Epoch 40/200
# 9/9 [==============================] - 0s 9ms/step - loss: 1.4409 - accuracy: 0.6357
# Epoch 41/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.1873 - accuracy: 0.7000
# Epoch 42/200
# 9/9 [==============================] - 0s 39ms/step - loss: 1.4244 - accuracy: 0.5643
# Epoch 43/200
# 9/9 [==============================] - 0s 16ms/step - loss: 1.3196 - accuracy: 0.6571
# Epoch 44/200
# 9/9 [==============================] - 0s 11ms/step - loss: 1.2551 - accuracy: 0.6500
# Epoch 45/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.2167 - accuracy: 0.6857
# Epoch 46/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.1246 - accuracy: 0.7286
# Epoch 47/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0125 - accuracy: 0.7286
# Epoch 48/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.1121 - accuracy: 0.7500
# Epoch 49/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.1019 - accuracy: 0.6429
# Epoch 50/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.1241 - accuracy: 0.6929
# Epoch 51/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1.1316 - accuracy: 0.6714
# Epoch 52/200
# 9/9 [==============================] - 0s 12ms/step - loss: 1.0186 - accuracy: 0.7643
# Epoch 53/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.9044 - accuracy: 0.7286
# Epoch 54/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8269 - accuracy: 0.7786
# Epoch 55/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.8679 - accuracy: 0.7429
# Epoch 56/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.9066 - accuracy: 0.7429
# Epoch 57/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.7258 - accuracy: 0.8643
# Epoch 58/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.8412 - accuracy: 0.7929
# Epoch 59/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.8669 - accuracy: 0.8000
# Epoch 60/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.6323 - accuracy: 0.8500
# Epoch 61/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.7644 - accuracy: 0.8214
# Epoch 62/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.7971 - accuracy: 0.7714
# Epoch 63/200
# 9/9 [==============================] - 0s 15ms/step - loss: 0.7137 - accuracy: 0.8357
# Epoch 64/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.8838 - accuracy: 0.7000
# Epoch 65/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.8043 - accuracy: 0.7571
# Epoch 66/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.7591 - accuracy: 0.8071
# Epoch 67/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.8852 - accuracy: 0.7429
# Epoch 68/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.7531 - accuracy: 0.7571
# Epoch 69/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.6576 - accuracy: 0.8357
# Epoch 70/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.6611 - accuracy: 0.8071
# Epoch 71/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.6820 - accuracy: 0.8357
# Epoch 72/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.6523 - accuracy: 0.8429
# Epoch 73/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.6555 - accuracy: 0.8214
# Epoch 74/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5536 - accuracy: 0.8714
# Epoch 75/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.6029 - accuracy: 0.8357
# Epoch 76/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.6247 - accuracy: 0.8214
# Epoch 77/200
# 9/9 [==============================] - 0s 14ms/step - loss: 0.7387 - accuracy: 0.7643
# Epoch 78/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5192 - accuracy: 0.8500
# Epoch 79/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5113 - accuracy: 0.8857
# Epoch 80/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5743 - accuracy: 0.8286
# Epoch 81/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5719 - accuracy: 0.8786
# Epoch 82/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5347 - accuracy: 0.8643
# Epoch 83/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.6551 - accuracy: 0.7714
# Epoch 84/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5666 - accuracy: 0.8286
# Epoch 85/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.5368 - accuracy: 0.8500
# Epoch 86/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5059 - accuracy: 0.8500
# Epoch 87/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5030 - accuracy: 0.8643
# Epoch 88/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5046 - accuracy: 0.8571
# Epoch 89/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4964 - accuracy: 0.8571
# Epoch 90/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5125 - accuracy: 0.8714
# Epoch 91/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4744 - accuracy: 0.8286
# Epoch 92/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5546 - accuracy: 0.8429
# Epoch 93/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4904 - accuracy: 0.8643
# Epoch 94/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4243 - accuracy: 0.8571
# Epoch 95/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5046 - accuracy: 0.8500
# Epoch 96/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5770 - accuracy: 0.8214
# Epoch 97/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4607 - accuracy: 0.8786
# Epoch 98/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5386 - accuracy: 0.8357
# Epoch 99/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4452 - accuracy: 0.8857
# Epoch 100/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4516 - accuracy: 0.8643
# Epoch 101/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3987 - accuracy: 0.8643
# Epoch 102/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4328 - accuracy: 0.8714
# Epoch 103/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4362 - accuracy: 0.8929
# Epoch 104/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4318 - accuracy: 0.9071
# Epoch 105/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4647 - accuracy: 0.8714
# Epoch 106/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3979 - accuracy: 0.8643
# Epoch 107/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4126 - accuracy: 0.9000
# Epoch 108/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3011 - accuracy: 0.9143
# Epoch 109/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3864 - accuracy: 0.8643
# Epoch 110/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5216 - accuracy: 0.8429
# Epoch 111/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4191 - accuracy: 0.8500
# Epoch 112/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4312 - accuracy: 0.8714
# Epoch 113/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4115 - accuracy: 0.8929
# Epoch 114/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4240 - accuracy: 0.8643
# Epoch 115/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3189 - accuracy: 0.8929
# Epoch 116/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3608 - accuracy: 0.9071
# Epoch 117/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3113 - accuracy: 0.9143
# Epoch 118/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3913 - accuracy: 0.9000
# Epoch 119/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2762 - accuracy: 0.9286
# Epoch 120/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3766 - accuracy: 0.9071
# Epoch 121/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3381 - accuracy: 0.8857
# Epoch 122/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3628 - accuracy: 0.8929
# Epoch 123/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3652 - accuracy: 0.9000
# Epoch 124/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3236 - accuracy: 0.8786
# Epoch 125/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3076 - accuracy: 0.8500
# Epoch 126/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2948 - accuracy: 0.9286
# Epoch 127/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3212 - accuracy: 0.8714
# Epoch 128/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3609 - accuracy: 0.8786
# Epoch 129/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3437 - accuracy: 0.8929
# Epoch 130/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3106 - accuracy: 0.9000
# Epoch 131/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2695 - accuracy: 0.9143
# Epoch 132/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3056 - accuracy: 0.9000
# Epoch 133/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3537 - accuracy: 0.9000
# Epoch 134/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2619 - accuracy: 0.9286
# Epoch 135/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2977 - accuracy: 0.8857
# Epoch 136/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3338 - accuracy: 0.9000
# Epoch 137/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3437 - accuracy: 0.8929
# Epoch 138/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3084 - accuracy: 0.9143
# Epoch 139/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2871 - accuracy: 0.9214
# Epoch 140/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3331 - accuracy: 0.8929
# Epoch 141/200
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3300 - accuracy: 0.9143
# Epoch 142/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2739 - accuracy: 0.9143
# Epoch 143/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3058 - accuracy: 0.9143
# Epoch 144/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3542 - accuracy: 0.9286
# Epoch 145/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3038 - accuracy: 0.8929
# Epoch 146/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3030 - accuracy: 0.9286
# Epoch 147/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3499 - accuracy: 0.8929
# Epoch 148/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2857 - accuracy: 0.9214
# Epoch 149/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2824 - accuracy: 0.9143
# Epoch 150/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3257 - accuracy: 0.8929
# Epoch 151/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3337 - accuracy: 0.8786
# Epoch 152/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2904 - accuracy: 0.9071
# Epoch 153/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2157 - accuracy: 0.9500
# Epoch 154/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2812 - accuracy: 0.8857
# Epoch 155/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2923 - accuracy: 0.9000
# Epoch 156/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2928 - accuracy: 0.9143
# Epoch 157/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2897 - accuracy: 0.9000
# Epoch 158/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2589 - accuracy: 0.9071
# Epoch 159/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2553 - accuracy: 0.9286
# Epoch 160/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1804 - accuracy: 0.9429
# Epoch 161/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3107 - accuracy: 0.8714
# Epoch 162/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2204 - accuracy: 0.9500
# Epoch 163/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2750 - accuracy: 0.9071
# Epoch 164/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2468 - accuracy: 0.8929
# Epoch 165/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2504 - accuracy: 0.9000
# Epoch 166/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2581 - accuracy: 0.9214
# Epoch 167/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2575 - accuracy: 0.9000
# Epoch 168/200
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2384 - accuracy: 0.9214
# Epoch 169/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2756 - accuracy: 0.9071
# Epoch 170/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2801 - accuracy: 0.8857
# Epoch 171/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2761 - accuracy: 0.9071
# Epoch 172/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2067 - accuracy: 0.9214
# Epoch 173/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2297 - accuracy: 0.9357
# Epoch 174/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2529 - accuracy: 0.9143
# Epoch 175/200
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2661 - accuracy: 0.8929
# Epoch 176/200
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1764 - accuracy: 0.9571
# Epoch 177/200
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2353 - accuracy: 0.9357
# Epoch 178/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2232 - accuracy: 0.9357
# Epoch 179/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2190 - accuracy: 0.9357
# Epoch 180/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2507 - accuracy: 0.9214
# Epoch 181/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2404 - accuracy: 0.9214
# Epoch 182/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2400 - accuracy: 0.9143
# Epoch 183/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3035 - accuracy: 0.8857
# Epoch 184/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2484 - accuracy: 0.9286
# Epoch 185/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2261 - accuracy: 0.9071
# Epoch 186/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2185 - accuracy: 0.9214
# Epoch 187/200
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2235 - accuracy: 0.9143
# Epoch 188/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2835 - accuracy: 0.8929
# Epoch 189/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2574 - accuracy: 0.9214
# Epoch 190/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2458 - accuracy: 0.9214
# Epoch 191/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2521 - accuracy: 0.8929
# Epoch 192/200
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2229 - accuracy: 0.9143
# Epoch 193/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2408 - accuracy: 0.9429
# Epoch 194/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2489 - accuracy: 0.9071
# Epoch 195/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2166 - accuracy: 0.9357
# Epoch 196/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2694 - accuracy: 0.9214
# Epoch 197/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2296 - accuracy: 0.9214
# Epoch 198/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2634 - accuracy: 0.8929
# Epoch 199/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2014 - accuracy: 0.9286
# Epoch 200/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2022 - accuracy: 0.9000

# %%
# saving the model
model.save('cancer_care_model1.1.h5', hist)

print("model created")
# Out:
# model created

# %%
from flask import Flask, jsonify
# from flask_cors import CORS, cross_origin
import random
import json
from tensorflow.keras.models import load_model
import numpy as np
import pickle
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()


intents = json.loads(open('/content/intents4.json', encoding="utf8").read())
words = pickle.load(open('/content/final_words.pkl', 'rb'))
classes = pickle.load(open('/content/final_classes.pkl', 'rb'))


def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(
        word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence


def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)
    for s in sentence_words:
        for i, w in enumerate(words):
            if w == s:
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print("found in bag: %s" % w)
    return(np.array(bag))


def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words, show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i, r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list


def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['context'] == tag):
            result = random.choice(i['answer'])
            break
    return result


def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res

def decrypt(msg):

    string = msg

    # converting back '+' character back into ' ' spaces
    # new_string is the normal message with spaces that was sent by the user
    new_string = string.replace("+", " ")

    return new_string
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-93d449383cd4> in <module>()
#      11
#      12
# ---> 13 intents = json.loads(open('/content/intents4.json', encoding="utf8").read())
#      14 words = pickle.load(open('/content/final_words.pkl', 'rb'))
#      15 classes = pickle.load(open('/content/final_classes.pkl', 'rb'))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/intents4.json'

# %%
# !pip install -U flask-cors
# Out:
# Collecting flask-cors
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: Six in /usr/local/lib/python3.7/dist-packages (from flask-cors) (1.15.0)
# Requirement already satisfied: Flask>=0.9 in /usr/local/lib/python3.7/dist-packages (from flask-cors) (1.1.4)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.9->flask-cors) (1.0.1)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.9->flask-cors) (2.11.3)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.9->flask-cors) (1.1.0)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.9->flask-cors) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=0.9->flask-cors) (2.0.1)
# Installing collected packages: flask-cors
# Successfully installed flask-cors-3.0.10

# %%
from flask import Flask, jsonify
from flask_cors import CORS, cross_origin
import random
import json
from tensorflow.keras.models import load_model
import numpy as np
import pickle
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
#from keras.models import load_model
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')

model = load_model('/content/final_chatbot_model1.h5')

intents = json.loads(open('/content/intents4.json', encoding="utf8").read())
words = pickle.load(open('/content/final_words.pkl', 'rb'))
classes = pickle.load(open('/content/final_classes.pkl', 'rb'))


def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(
        word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence


def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)
    for s in sentence_words:
        for i, w in enumerate(words):
            if w == s:
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print("found in bag: %s" % w)
    return(np.array(bag))


def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words, show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i, r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list


def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['context'] == tag):
            result = random.choice(i['answer'])
            break
    return result


def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res


''' Flask code '''


app = Flask(__name__)
CORS(app)


@app.route("/", methods=['GET', 'POST'])
def hello():
    return jsonify({"key": "home page value"})

# function to replace '+' character with ' ' spaces


def decrypt(msg):

    string = msg

    # converting back '+' character back into ' ' spaces
    # new_string is the normal message with spaces that was sent by the user
    new_string = string.replace("+", " ")

    return new_string

# here we will send a string from the client and the server will return another
# string with som modification
# creating a url dynamically


@app.route('/home/<name>')
def hello_name(name):

    # dec_msg is the real question asked by the user
    dec_msg = decrypt(name)

    # get the response from the ML model & dec_msg as the argument
    response = chatbot_response(dec_msg)

    # creating a json object
    json_obj = jsonify({"top": {"res": response}})

    return json_obj


if __name__ == '__main__':
    app.run(debug=True)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/omw-1.4.zip.
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
